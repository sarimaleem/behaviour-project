# %%
import  numpy as np
import matplotlib.pyplot as plt
x = np.arange(0, 5, 0.01)
y = np.zeros(500)
y[100:400] = 1
y += np.random.randn(500) * 0.05
plt.plot(x, y)
plt.show()

# %%
# %matplotlib inline
from ipywidgets import interact, interactive
from IPython.display import clear_output, display, HTML

def test():
    print(np.random.randn(5))

w = interactive(test)
display(w)
# Out:
# [-0.85266071 -0.72461336  0.67036078 -0.19921144  1.89801306]
